# %% [markdown]
# # Shahid Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Shahid Mian**
#
# Data Specialist

# %% [markdown]
# _I am interested in Data Science because I like to support and help the community in the future_

# %% [markdown]
# ### The below should print 'Hello World'

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# > You miss 100% of the shots you don't take
# >
#  - Wayne Gretzky
#  - Micheal Scott
#
# <hr>
#
# Made with <3 [My Github](https://github.com/shahidmian1)
